# %%
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()

# %%
from sqlalchemy import create_engine

# %%
connection = "mysql+pymysql://root:Londo105@localhost/sakila"

# %%
engine = create_engine(connection)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %%
q = """SELECT * FROM customer;"""
pd.read_sql(q, engine)
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  active  \
# 0            MARY.SMITH@sakilacustomer.org           5       1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3         BARBARA.JONES@sakilacustomer.org           8       1
# 4       ELIZABETH.BROWN@sakilacustomer.org           9       1
# ..                                     ...         ...     ...
# 594  TERRENCE.GUNDERSON@sakilacustomer.org         601       1
# 595    ENRIQUE.FORSYTHE@sakilacustomer.org         602       1
# 596      FREDDIE.DUGGAN@sakilacustomer.org         603       1
# 597       WADE.DELVALLE@sakilacustomer.org         604       1
# 598      AUSTIN.CINTRON@sakilacustomer.org         605       1
#
#             create_date         last_update
# 0   2006-02-14 22:04:36 2006-02-14 12:57:20
# 1   2006-02-14 22:04:36 2006-02-14 12:57:20
# 2   2006-02-14 22:04:36 2006-02-14 12:57:20
# 3   2006-02-14 22:04:36 2006-02-14 12:57:20
# 4   2006-02-14 22:04:36 2006-02-14 12:57:20
# ..                  ...                 ...
# 594 2006-02-14 22:04:37 2006-02-14 12:57:20
# 595 2006-02-14 22:04:37 2006-02-14 12:57:20
# 596 2006-02-14 22:04:37 2006-02-14 12:57:20
# 597 2006-02-14 22:04:37 2006-02-14 12:57:20
# 598 2006-02-14 22:04:37 2006-02-14 12:57:20
#
# [599 rows x 9 columns]

# %%
q = """SELECT * FROM city;"""
pd.read_sql(q, engine)
# Out:
#      city_id                city  country_id         last_update
# 0          1  A Corua (La Corua)          87 2006-02-14 12:45:25
# 1          2                Abha          82 2006-02-14 12:45:25
# 2          3           Abu Dhabi         101 2006-02-14 12:45:25
# 3          4                Acua          60 2006-02-14 12:45:25
# 4          5               Adana          97 2006-02-14 12:45:25
# ..       ...                 ...         ...                 ...
# 595      596               Zaria          69 2006-02-14 12:45:25
# 596      597        Zeleznogorsk          80 2006-02-14 12:45:25
# 597      598         Zhezqazghan          51 2006-02-14 12:45:25
# 598      599            Zhoushan          23 2006-02-14 12:45:25
# 599      600          Ziguinchor          83 2006-02-14 12:45:25
#
# [600 rows x 4 columns]

# %%
# 1. What query would you run to get all the customers inside city_id = 312? Your query should return the customers' first name, last name, email, address, and city.

# %%
q = "SELECT customer.first_name, customer.last_name, customer.email, address.address, city.city
FROM customer
JOIN city, address
ON city.city_id = address.city_id and address.address_id = customer.address_id
WHERE city.city_id = '312';"
pd.read_sql(q, engine)
# Out:
#   File "/var/folders/5r/zc_b9hw50yg140wk0zyqjcs80000gn/T/ipykernel_44802/369080624.py", line 1
#     q = "SELECT customer.first_name, customer.last_name, customer.email, address.address, city.city
#                                                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
# 2. What query would you run to get all comedy films? Note that the genre is called the category in this schema.  Your query should return film title, description, release year, rating, and special features.

# %%
SELECT film.title, film.description, film.release_year, film.rating, film.special_features
FROM film
JOIN film_category, category
ON film.film_id = film_category.film_id and film_category.category_id = category.category_id
WHERE category.name = "Comedy";

# %%
# 3. What query would you run to get all the films that Johnny Lollobrigida was in? Your query should return the actor's last name, film title, and release year.

# %%
SELECT actor.last_name, film.title, film.release_year
FROM film
JOIN film_category, film_actor
ON film.film_id = film_actor.film_id and film_actor.actor_id = actor.actor_id
WHERE actor.last_name = "Lollobrigida";

# %%
# # 4. What query would you run to get the first and last names of all the actors in the movie titled "Bingo Talented"?

# %%
SELECT actor.first_name, actor.last_name
FROM actor
JOIN film, film_actor
ON actor.actor_id = film_actor.actor_id and film.film_id = film_actor.film_id
WHERE film.title = "Bingo Talented";

# %%
# 5. What query would you run to get the customer_id associated with all payments greater than twice the average payment amount? (HINT: use 2* in your query to get twice the amount). Your result should include the customer id and the amount.

# %%
SELECT customer_id
FROM customer 
JOIN payment
ON customer.customer_id = payment.customer_id
WHERE payment.amount >
			(SELECT 2*AVG(payment)
            FROM payment);

# %%
# 6. What query would you run to list the first and last names of the 5 customers who have the highest number(count) of payments? You can title the number of payments as num_payments.

# %%
 SELECT customer.first_name, customer.last_name
 JOIN payment
  (SELECT COUNT(*)
   FROM payment.amount
   WHERE customer.customer_id = payment.customer_id) AS num_payments
FROM payment
ORDER by num_payment DESC;
